# %% [markdown]
# # Data Cleaning and Organization
#
# Combine all of the datasets into full csv dataframes for EDA and modeling use

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Clean Demographics Data

# %%
demographics = pd.read_csv("../data/base_data/california_county_data.csv")

# %%
demographics.head()
# Out:
#       County population Race/Ethnicity: Asian Race/Ethnicity: AAPI  \
# 0    Alameda  1,669,301               443,972              457,606
# 1     Alpine      1,162                     6                    6
# 2     Amador     38,294                   454                  518
# 3      Butte    226,466                10,141                10615
# 4  Calaveras     45,117                   589                  660
#
#   Race/Ethnicity: Black Race/Ethnicity: Hispanic  \
# 0               192,977                  391,815
# 1                     1                       85
# 2                 1,024                    5,311
# 3                 3,666                   35,848
# 4                   371                    5,114
#
#   Race/Ethnicity: Multi-Racial/Ethnic  \
# 0                              69,855
# 1                                  22
# 2                               1,021
# 3                               8,801
# 4                               1,320
#
#   Race/Ethnicity: Hawaiian/ Pacific Island Race/Ethnicity: White  \
# 0                                   13,634               562,667
# 1                                        0                   830
# 2                                       64                29,802
# 3                                      474               166,738
# 4                                       71                36,745
#
#   Labor Force: Unemployment Rate (2018) Poverty: Under 18 Percent (2017)  \
# 0                                 3.00%                           10.50%
# 1                                 4.60%                           35.30%
# 2                                 4.00%                           15.70%
# 3                                 4.90%                           22.60%
# 4                                 4.00%                           21.10%
#
#   Median Household Income (2017)
# 0                    $95,550.00
# 1                    $55,755.00
# 2                    $60,588.00
# 3                    $48,634.00
# 4                    $58,536.00

# %% [markdown]
# ### Clean & Format Data

# %%
#remove , and $
demographics = demographics.replace(",","", regex=True)
demographics.iloc[:,-1] = demographics.iloc[:,-1].str[1:]

#clean percentages
demographics.iloc[:,9] = demographics.iloc[:,9].map(lambda x: float(x[:-1])/100)
demographics.iloc[:,10] = demographics.iloc[:,10].map(lambda x: float(x[:-1])/100)

# %%
# Set dtype to floats
demographics.iloc[:,1:] = demographics.iloc[:,1:].astype('float')

# %%
#Convert Demographics data into percentages
for i in range(2,9):
    demographics.iloc[:,i] = demographics.iloc[:,i]/demographics.iloc[:,1]

# %%
#remove space in county name
demographics['County'] = demographics['County'].str.replace(" ", "")

# %% [markdown]
# ### Rename Columns

# %%
#rename columns
col_map = {demographics.columns[i] : "pct_" + demographics.columns[i][16:] for i in range(2,9)}
demographics.rename(col_map, axis=1, inplace=True)

# %%
#rename remaining columns
col_map2 = {
    "Labor Force: Unemployment Rate (2018)" : "pct_unemployed_2018",
    "Poverty: Under 18 Percent (2017)" : 'pct_u18_poverty_2017',
    "Median Household Income (2017)" : "median_hh_income_2017"
}
demographics.rename(col_map2, axis=1, inplace=True)

# %%
demographics.head(3)
# Out:
#     County  population  pct_Asian  pct_AAPI  pct_Black  pct_Hispanic  \
# 0  Alameda   1669301.0   0.265963  0.274130   0.115603      0.234718
# 1   Alpine      1162.0   0.005164  0.005164   0.000861      0.073150
# 2   Amador     38294.0   0.011856  0.013527   0.026740      0.138690
#
#    pct_Multi-Racial/Ethnic  pct_Hawaiian/ Pacific Island  pct_White  \
# 0                 0.041847                      0.008167   0.337067
# 1                 0.018933                      0.000000   0.714286
# 2                 0.026662                      0.001671   0.778242
#
#    pct_unemployed_2018  pct_u18_poverty_2017  median_hh_income_2017
# 0                0.030                 0.105                95550.0
# 1                0.046                 0.353                55755.0
# 2                0.040                 0.157                60588.0

# %% [markdown]
# ## Clean base data

# %%
codebook_df = pd.read_excel("../data/base_data/County_codebook.xlsx")
hate_crimes = pd.read_csv("../data/base_data/Hate-2001-2020.csv")

# %%
hate_crimes.head()
# Out:
#           RecordId  ClosedYear  MonthOccurrence  County NCIC  \
# 0  CA01-0000000001        2001                2       1  100
# 1  CA01-0000000005        2001                2       1  100
# 2  CA01-0000000003        2001                5       1  100
# 3  CA01-0000000002        2001                9       1  100
# 4  CA01-0000000004        2001                9       1  100
#
#    TotalNumberOfVictims  TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  \
# 0                     1                               1                White
# 1                     2                               2                White
# 2                     1                               1                White
# 3                     1                               1                White
# 4                     2                               2                White
#
#    TotalNumberOfSuspects                MostSeriousUcr  ...  \
# 0                      2                Simple Assault  ...
# 1                      1  Destruction/Damage/Vandalism  ...
# 2                      4  Destruction/Damage/Vandalism  ...
# 3                      1                  Intimidation  ...
# 4                      1                  Intimidation  ...
#
#        MostSeriousBiasType MostSeriousVictimType  \
# 0  Race/Ethnicity/Ancestry                Person
# 1  Race/Ethnicity/Ancestry                Person
# 2  Race/Ethnicity/Ancestry                Person
# 3  Race/Ethnicity/Ancestry                Person
# 4  Race/Ethnicity/Ancestry                Person
#
#                                     WeaponType        Offensive_Act  \
# 0  Personal weapons (hands, feet, teeth, etc.)         Verbal slurs
# 1                                          NaN             Graffiti
# 2                                          NaN  Daubing of swastika
# 3                                          NaN         Verbal slurs
# 4                                          NaN         Verbal slurs
#
#   IsMultipleBias TotalNumberOfIndividualVictimsAdult  \
# 0            NaN                                 NaN
# 1            NaN                                 NaN
# 2            NaN                                 NaN
# 3            NaN                                 NaN
# 4            NaN                                 NaN
#
#   TotalNumberOfIndividualVictimsJuvenile TotalNumberOfSuspectsAdult  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
#
#    TotalNumberOfSuspectsJuvenile  SuspectsEthnicityAsAGroup
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Map County & Agency names to code numbers

# %%
#Get County and Agency Data
county_codes = codebook_df['CntyCode'].unique()
counties = codebook_df['County'].unique()

#Created dictionaries for mapping
sliced_counties = []
for county in counties:
    sliced_counties.append(county[:-7])
county_dictionary = {county_codes[i] : sliced_counties[i] for i in range(len(county_codes))}

agency_dictionary = {}
for i in range(codebook_df.shape[0]):
    try:
        agency_dictionary[codebook_df['Code'][i].lstrip('0')] = codebook_df['Agency'][i]
    except:
        agency_dictionary[codebook_df['Code'][i]] = codebook_df['Agency'][i]

#Map Counties and Agencies to respective codes
hate_crimes['County'] = hate_crimes['County'].map(county_dictionary)
hate_crimes['NCIC'] = hate_crimes['NCIC'].map(agency_dictionary)

# %%
hate_crimes.head(3)
# Out:
#           RecordId  ClosedYear  MonthOccurrence   County  \
# 0  CA01-0000000001        2001                2  Alameda
# 1  CA01-0000000005        2001                2  Alameda
# 2  CA01-0000000003        2001                5  Alameda
#
#                                NCIC  TotalNumberOfVictims  \
# 0  Alameda Co. Sheriff's Department                     1
# 1  Alameda Co. Sheriff's Department                     2
# 2  Alameda Co. Sheriff's Department                     1
#
#    TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  TotalNumberOfSuspects  \
# 0                               1                White                      2
# 1                               2                White                      1
# 2                               1                White                      4
#
#                  MostSeriousUcr  ...      MostSeriousBiasType  \
# 0                Simple Assault  ...  Race/Ethnicity/Ancestry
# 1  Destruction/Damage/Vandalism  ...  Race/Ethnicity/Ancestry
# 2  Destruction/Damage/Vandalism  ...  Race/Ethnicity/Ancestry
#
#   MostSeriousVictimType                                   WeaponType  \
# 0                Person  Personal weapons (hands, feet, teeth, etc.)
# 1                Person                                          NaN
# 2                Person                                          NaN
#
#          Offensive_Act IsMultipleBias TotalNumberOfIndividualVictimsAdult  \
# 0         Verbal slurs            NaN                                 NaN
# 1             Graffiti            NaN                                 NaN
# 2  Daubing of swastika            NaN                                 NaN
#
#   TotalNumberOfIndividualVictimsJuvenile TotalNumberOfSuspectsAdult  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
#
#    TotalNumberOfSuspectsJuvenile  SuspectsEthnicityAsAGroup
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
#
# [3 rows x 23 columns]

# %%
#remove space in County
hate_crimes['County'] = hate_crimes['County'].str.replace(" ", "")

# %%
#drop unwanted columns
hate_crimes.drop(hate_crimes.iloc[:, 17:23], axis=1, inplace=True)

#fill NAs
hate_crimes['WeaponType'].fillna('None', inplace=True)
hate_crimes['Offensive_Act'].fillna('Other', inplace=True)

# %%
hate_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24436 entries, 0 to 24435
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RecordId                        24436 non-null  object
#  1   ClosedYear                      24436 non-null  int64
#  2   MonthOccurrence                 24436 non-null  int64
#  3   County                          24436 non-null  object
#  4   NCIC                            24436 non-null  object
#  5   TotalNumberOfVictims            24436 non-null  int64
#  6   TotalNumberOfIndividualVictims  24436 non-null  int64
#  7   SuspectsRaceAsAGroup            24436 non-null  object
#  8   TotalNumberOfSuspects           24436 non-null  int64
#  9   MostSeriousUcr                  24436 non-null  object
#  10  MostSeriousUcrType              24436 non-null  object
#  11  MostSeriousLocation             24436 non-null  object
#  12  MostSeriousBias                 24436 non-null  object
#  13  MostSeriousBiasType             24436 non-null  object
#  14  MostSeriousVictimType           24436 non-null  object
#  15  WeaponType                      24436 non-null  object
#  16  Offensive_Act                   24436 non-null  object
# dtypes: int64(5), object(12)
# memory usage: 3.2+ MB

# %%
hate_crimes.to_csv("../data/cleaned_hate_crimes.csv", index=False)

# %% [markdown]
# ## Clean Prosecution Data

# %%
prosecution = pd.read_csv("../data/base_data/Hate-Prosecution-survey-2004-2020.csv")
prosecution.head(3)
# Out:
#    Year Agency Type Agency Name Total Hate Crime Cases Referred  \
# 0  2004   County DA     Alameda                               2
# 1  2004   County DA      Alpine                               0
# 2  2004   County DA      Amador                               1
#
#   Total Cases Filed as Hate Crimes  \
# 0                                2
# 1                                0
# 2                                1
#
#   Total Cases Filed as Non-Bias Motivated Crimes Total Dispositions  \
# 0                                              0                  2
# 1                                              0                  0
# 2                                              0                  1
#
#   Not Convicted Total Convictions Total Hate Crime Convictions  \
# 0             1                 1                            1
# 1             0                 0                            0
# 2             0                 1                            0
#
#   Guilty plea/Nolo contendere Trial Verdict All Other Convictions
# 0                           1             0                     0
# 1                           0             0                     0
# 2                           0             0                     1

# %%
prosecution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1146 entries, 0 to 1145
# Data columns (total 13 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Year                                            1146 non-null   int64
#  1   Agency Type                                     1146 non-null   object
#  2   Agency Name                                     1146 non-null   object
#  3   Total Hate Crime Cases Referred                 1050 non-null   object
#  4   Total Cases Filed as Hate Crimes                1050 non-null   object
#  5   Total Cases Filed as Non-Bias Motivated Crimes  1050 non-null   object
#  6   Total Dispositions                              1146 non-null   object
#  7   Not Convicted                                   1050 non-null   object
#  8   Total Convictions                               1146 non-null   object
#  9   Total Hate Crime Convictions                    1146 non-null   object
#  10  Guilty plea/Nolo contendere                     1050 non-null   object
#  11  Trial Verdict                                   1050 non-null   object
#  12  All Other Convictions                           1050 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 116.5+ KB

# %% [markdown]
# ### Convert Relevant Object Columns to int

# %%
# Columns to convert
for col in prosecution.iloc[:, 3:].columns:
    # Change rows with "-" to 0
    prosecution[col] = prosecution[col].str.replace("-", "0")
    # Fill NaNs with 0
    prosecution[col].fillna(0, inplace=True)
    # Change dtype to int
    prosecution[col] = prosecution[col].astype(int)

prosecution.dtypes
# Out:
# Year                                               int64
# Agency Type                                       object
# Agency Name                                       object
# Total Hate Crime Cases Referred                    int64
# Total Cases Filed as Hate Crimes                   int64
# Total Cases Filed as Non-Bias Motivated Crimes     int64
# Total Dispositions                                 int64
# Not Convicted                                      int64
# Total Convictions                                  int64
# Total Hate Crime Convictions                       int64
# Guilty plea/Nolo contendere                        int64
# Trial Verdict                                      int64
# All Other Convictions                              int64
# dtype: object

# %% [markdown]
# ### Group data by Agency Name (county) and aggregate for all years

# %%
# Look at Agency Name, mostly counties
prosecution["Agency Name"].unique()
# Out:
# array(['Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa',
#        'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno', 'Glenn',
#        'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen',
#        'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino',
#        'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange',
#        'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito',
#        'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin',
#        'San Luis Obispo', 'San Mateo', 'Santa Barbara', 'Santa Clara',
#        'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 'Solano', 'Sonoma',
#        'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne',
#        'Ventura', 'Yolo', 'Yuba', 'Anaheim', 'Burbank', 'Inglewood',
#        'Long Beach', 'Pasadena', 'Torrance', 'Chula Vista', 'Compton',
#        'Huntington Beach', 'Oakland', 'Redondo Beach', 'San Rafael',
#        'ContraCosta', 'DelNorte', 'ElDorado', 'LosAngeles', 'SanBenito',
#        'SanBernardino', 'SanDiego', 'SanFrancisco', 'SanJoaquin',
#        'SanLuisObispo', 'SanMateo', 'SantaBarbara', 'SantaClara',
#        'SantaCruz', '  Chula Vista', '  Compton', '  Huntington Beach',
#        '  Long Beach', '  Los Angeles', '  Oakland', '  Redondo Beach',
#        '  San Bernardino', '  San Diego', '  San Francisco',
#        '  San Rafael'], dtype=object)

# %%
prosecution["Agency Type"].unique()
# Out:
# array(['County DA', 'Elected City Attorney'], dtype=object)

# %%
# Strip spaces in some counties
prosecution["Agency Name"] = prosecution["Agency Name"].str.replace(" ", "")
prosecution["Agency Name"].unique()
# Out:
# array(['Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa',
#        'ContraCosta', 'DelNorte', 'ElDorado', 'Fresno', 'Glenn',
#        'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen',
#        'LosAngeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino', 'Merced',
#        'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange', 'Placer',
#        'Plumas', 'Riverside', 'Sacramento', 'SanBenito', 'SanBernardino',
#        'SanDiego', 'SanFrancisco', 'SanJoaquin', 'SanLuisObispo',
#        'SanMateo', 'SantaBarbara', 'SantaClara', 'SantaCruz', 'Shasta',
#        'Sierra', 'Siskiyou', 'Solano', 'Sonoma', 'Stanislaus', 'Sutter',
#        'Tehama', 'Trinity', 'Tulare', 'Tuolumne', 'Ventura', 'Yolo',
#        'Yuba', 'Anaheim', 'Burbank', 'Inglewood', 'LongBeach', 'Pasadena',
#        'Torrance', 'ChulaVista', 'Compton', 'HuntingtonBeach', 'Oakland',
#        'RedondoBeach', 'SanRafael'], dtype=object)

# %%
# Drop Elected City Attorneys
prosecution = prosecution[prosecution["Agency Type"] == "County DA"]
prosecution["Agency Type"].unique()
# Out:
# array(['County DA'], dtype=object)

# %%
# Groupby and aggregate (sum)
prosecution_all_years = prosecution.drop(columns="Year").groupby(by="Agency Name").sum()
prosecution_all_years.reset_index(inplace=True)

# %% [markdown]
# ### Visualize counties by number of hate crimes referred

# %%
# See counties with most Hate Crimes
prosecution_all_years.sort_values(
    by="Total Hate Crime Cases Referred", ascending=False
).head(20)
# Out:
#       Agency Name  Total Hate Crime Cases Referred  \
# 18     LosAngeles                             1871
# 36       SanDiego                              444
# 37   SanFrancisco                              403
# 29         Orange                              371
# 32      Riverside                              335
# 42     SantaClara                              274
# 55        Ventura                              179
# 0         Alameda                              167
# 33     Sacramento                              141
# 44         Shasta                              123
# 35  SanBernardino                              118
# 43      SantaCruz                               94
# 56           Yolo                               89
# 6     ContraCosta                               85
# 39  SanLuisObispo                               77
# 40       SanMateo                               75
# 26       Monterey                               64
# 3           Butte                               61
# 38     SanJoaquin                               60
# 9          Fresno                               56
#
#     Total Cases Filed as Hate Crimes  \
# 18                              1337
# 36                               295
# 37                               235
# 29                               195
# 32                               176
# 42                               127
# 55                               117
# 0                                116
# 33                                74
# 44                                91
# 35                                98
# 43                                47
# 56                                48
# 6                                 80
# 39                                55
# 40                                50
# 26                                42
# 3                                 34
# 38                                52
# 9                                 51
#
#     Total Cases Filed as Non-Bias Motivated Crimes  Total Dispositions  \
# 18                                             176                 954
# 36                                              79                 259
# 37                                              57                 141
# 29                                              73                 191
# 32                                             103                 179
# 42                                              74                  70
# 55                                              36                  70
# 0                                                2                  86
# 33                                              26                  52
# 44                                              27                  68
# 35                                               7                  79
# 43                                              28                  44
# 56                                              24                  44
# 6                                               12                  75
# 39                                              17                  31
# 40                                               1                  35
# 26                                              14                  37
# 3                                               19                  21
# 38                                               3                  33
# 9                                               10                  39
#
#     Not Convicted  Total Convictions  Total Hate Crime Convictions  \
# 18            144                810                           457
# 36              5                254                           150
# 37             20                121                            76
# 29              8                183                           152
# 32              4                175                            94
# 42              3                 67                            48
# 55              4                 66                            56
# 0              11                 75                            24
# 33              1                 51                            30
# 44             15                 53                            22
# 35              7                 72                            14
# 43              6                 38                            19
# 56              7                 37                            19
# 6              25                 50                            15
# 39             11                 20                            14
# 40              5                 30                            16
# 26              1                 36                            20
# 3               2                 19                            10
# 38              3                 30                            14
# 9               5                 34                            16
#
#     Guilty plea/Nolo contendere  Trial Verdict  All Other Convictions
# 18                          269            188                    353
# 36                          144              6                    104
# 37                           66             10                     45
# 29                          147              5                     31
# 32                           83             11                     81
# 42                           47              1                     19
# 55                           45             11                     10
# 0                            24              0                     51
# 33                           28              2                     21
# 44                           22              0                     31
# 35                           14              0                     58
# 43                           19              0                     19
# 56                           18              1                     18
# 6                            14              1                     35
# 39                           14              0                      6
# 40                           15              1                     14
# 26                           19              1                     16
# 3                             9              1                      9
# 38                           13              1                     16
# 9                            13              3                     18

# %% [markdown]
# ### Merge with Demographics Data

# %%
prosecution_demo_all_years = pd.merge(left=prosecution_all_years, right=demographics, left_on='Agency Name', right_on='County')

# %% [markdown]
# ### Save Clean Prosecution Data

# %%
prosecution_all_years.to_csv("../data/prosecution_all_years.csv", index=False)
prosecution_demo_all_years.to_csv("../data/demographics-data/prosecution_all_years_demographics.csv", index=False)

# %% [markdown]
# ### Create Prosecution Rate

# %%
prosecution_all_years["prosecution-rate"] = prosecution_all_years[
    "Total Dispositions"
].astype(int) / prosecution_all_years["Total Hate Crime Cases Referred"].astype(int)

prosecution_demo_all_years["prosecution-rate"] = prosecution_demo_all_years[
    "Total Dispositions"
].astype(int) / prosecution_demo_all_years["Total Hate Crime Cases Referred"].astype(int)

# %%
prosecution_all_years['prosecution-rate'].mean()
# Out:
# 0.5499405648949045

# %%
## Visualize
prosecution_all_years.sort_values(by="prosecution-rate", ascending=False).head(20)
# Out:
#       Agency Name  Total Hate Crime Cases Referred  \
# 14           Kern                               43
# 10          Glenn                                7
# 13           Inyo                               11
# 4       Calaveras                                4
# 6     ContraCosta                               85
# 54       Tuolumne                                7
# 2          Amador                                5
# 50         Sutter                                5
# 9          Fresno                               56
# 35  SanBernardino                              118
# 46       Siskiyou                                6
# 12       Imperial                                3
# 48         Sonoma                               46
# 49     Stanislaus                               23
# 15          Kings                               23
# 7        DelNorte                               11
# 17         Lassen                                5
# 36       SanDiego                              444
# 26       Monterey                               64
# 19         Madera                                7
#
#     Total Cases Filed as Hate Crimes  \
# 14                                77
# 10                                 7
# 13                                 8
# 4                                  4
# 6                                 80
# 54                                 4
# 2                                  5
# 50                                 3
# 9                                 51
# 35                                98
# 46                                 6
# 12                                 1
# 48                                29
# 49                                16
# 15                                14
# 7                                  5
# 17                                 0
# 36                               295
# 26                                42
# 19                                 6
#
#     Total Cases Filed as Non-Bias Motivated Crimes  Total Dispositions  \
# 14                                               7                  64
# 10                                               0                  10
# 13                                               2                  12
# 4                                                0                   4
# 6                                               12                  75
# 54                                               0                   6
# 2                                                0                   4
# 50                                               1                   4
# 9                                               10                  39
# 35                                               7                  79
# 46                                               0                   4
# 12                                               0                   2
# 48                                               8                  30
# 49                                               2                  15
# 15                                               7                  15
# 7                                                7                   7
# 17                                               3                   3
# 36                                              79                 259
# 26                                              14                  37
# 19                                               1                   4
#
#     Not Convicted  Total Convictions  Total Hate Crime Convictions  \
# 14              3                 61                            19
# 10              0                 10                             5
# 13              0                 12                             4
# 4               1                  3                             0
# 6              25                 50                            15
# 54              0                  6                             5
# 2               0                  4                             2
# 50              0                  4                             1
# 9               5                 34                            16
# 35              7                 72                            14
# 46              2                  2                             1
# 12              0                  2                             2
# 48              6                 24                            12
# 49              1                 14                             4
# 15              0                 15                            11
# 7               0                  7                             4
# 17              0                  3                             0
# 36              5                254                           150
# 26              1                 36                            20
# 19              1                  3                             2
#
#     Guilty plea/Nolo contendere  Trial Verdict  All Other Convictions  \
# 14                           19              0                     42
# 10                            5              0                      5
# 13                            4              0                      8
# 4                             0              0                      3
# 6                            14              1                     35
# 54                            5              0                      1
# 2                             2              0                      2
# 50                            1              0                      3
# 9                            13              3                     18
# 35                           14              0                     58
# 46                            1              0                      1
# 12                            2              0                      0
# 48                           12              0                     12
# 49                            4              0                     10
# 15                           11              0                      4
# 7                             4              0                      3
# 17                            0              0                      3
# 36                          144              6                    104
# 26                           19              1                     16
# 19                            2              0                      1
#
#     prosecution-rate
# 14          1.488372
# 10          1.428571
# 13          1.090909
# 4           1.000000
# 6           0.882353
# 54          0.857143
# 2           0.800000
# 50          0.800000
# 9           0.696429
# 35          0.669492
# 46          0.666667
# 12          0.666667
# 48          0.652174
# 49          0.652174
# 15          0.652174
# 7           0.636364
# 17          0.600000
# 36          0.583333
# 26          0.578125
# 19          0.571429

# %%
sns.histplot(prosecution_all_years["prosecution-rate"])
;
plt.savefig('../plots/prosecution-rates-by-county.png')

# %%
prosecution_all_years['prosecution-rate'].describe()
# Out:
# count    52.000000
# mean      0.549941
# std       0.282699
# min       0.000000
# 25%       0.390518
# 50%       0.531315
# 75%       0.652174
# max       1.488372
# Name: prosecution-rate, dtype: float64

# %% [markdown]
# Looks fairly normally distributed though a bit skewed

# %% [markdown]
# ### Create Target variable by mapping prosecution rates to three categories
# 0 - Prosecution not likely (Low Prosecution Rate)
#
# 1 - Prosecution likely (Medium Prosecution Rate)
#
# 2 - Prosecution very likely (High Prosecution Rate)

# %%
# Check distribution for mapping
prosecution_all_years["prosecution-rate"].describe()
# Out:
# count    52.000000
# mean      0.549941
# std       0.282699
# min       0.000000
# 25%       0.390518
# 50%       0.531315
# 75%       0.652174
# max       1.488372
# Name: prosecution-rate, dtype: float64

# %%
#Create Labels based on 25, 50, and 75 percentiles
# With help from https://stackoverflow.com/questions/33439434/multiple-if-statements-in-a-lambda-function
prosecution_all_years["labels"] = prosecution_all_years["prosecution-rate"].map(
    lambda x: 0
    if x < prosecution_all_years["prosecution-rate"].describe()["25%"]
    else 1
    if x < prosecution_all_years["prosecution-rate"].describe()["75%"]
    else 2
)

# %%
prosecution_all_years["labels"].value_counts()
# Out:
# 1    24
# 2    21
# 0    13
# Name: labels, dtype: int64

# %%
#add labels to demographics dataframe
prosecution_demo_all_years['labels'] = prosecution_all_years['labels']

# %% [markdown]
# ### Save Labels

# %%
prosecution_labels = prosecution_all_years[["Agency Name", "labels"]]
prosecution_rates = prosecution_all_years[["Agency Name", "prosecution-rate"]]

# %% [markdown]
# ## Create Main DataFrame

# %%
#re-read cleaned data
df = pd.read_csv("../data/cleaned_hate_crimes.csv")
df.head(2)
# Out:
#           RecordId  ClosedYear  MonthOccurrence   County  \
# 0  CA01-0000000001        2001                2  Alameda
# 1  CA01-0000000005        2001                2  Alameda
#
#                                NCIC  TotalNumberOfVictims  \
# 0  Alameda Co. Sheriff's Department                     1
# 1  Alameda Co. Sheriff's Department                     2
#
#    TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  TotalNumberOfSuspects  \
# 0                               1                White                      2
# 1                               2                White                      1
#
#                  MostSeriousUcr MostSeriousUcrType      MostSeriousLocation  \
# 0                Simple Assault     Violent Crimes           Bar/Night Club
# 1  Destruction/Damage/Vandalism    Property Crimes  Residence/Home/Driveway
#
#                   MostSeriousBias      MostSeriousBiasType  \
# 0  Anti-Black or African American  Race/Ethnicity/Ancestry
# 1  Anti-Black or African American  Race/Ethnicity/Ancestry
#
#   MostSeriousVictimType                                   WeaponType  \
# 0                Person  Personal weapons (hands, feet, teeth, etc.)
# 1                Person                                         None
#
#   Offensive_Act
# 0  Verbal slurs
# 1      Graffiti

# %% [markdown]
# ### Merge with Prosecution data

# %% [markdown]
# #### Prosecution Labels

# %%
# Merge
modeling_data_l = df.merge(
    prosecution_labels, left_on="County", right_on="Agency Name"
)

# %%
#sanity check
print(modeling_data_l['labels'].value_counts())
print(modeling_data_l.shape)
# Out:
# 1    17800
# 0     4123
# 2     2513
# Name: labels, dtype: int64
# (24436, 19)

# %% [markdown]
# #### Prosecution Rates

# %%
# Merge on County
modeling_data_r = df.merge(
    prosecution_rates, left_on="County", right_on="Agency Name"
)

# %%
#sanity check
modeling_data_r.shape
# Out:
# (24436, 19)

# %%
#drop NAs
modeling_data_r.dropna(inplace=True)
modeling_data_r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24413 entries, 0 to 24434
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RecordId                        24413 non-null  object
#  1   ClosedYear                      24413 non-null  int64
#  2   MonthOccurrence                 24413 non-null  int64
#  3   County                          24413 non-null  object
#  4   NCIC                            24413 non-null  object
#  5   TotalNumberOfVictims            24413 non-null  int64
#  6   TotalNumberOfIndividualVictims  24413 non-null  int64
#  7   SuspectsRaceAsAGroup            24413 non-null  object
#  8   TotalNumberOfSuspects           24413 non-null  int64
#  9   MostSeriousUcr                  24413 non-null  object
#  10  MostSeriousUcrType              24413 non-null  object
#  11  MostSeriousLocation             24413 non-null  object
#  12  MostSeriousBias                 24413 non-null  object
#  13  MostSeriousBiasType             24413 non-null  object
#  14  MostSeriousVictimType           24413 non-null  object
#  15  WeaponType                      24413 non-null  object
#  16  Offensive_Act                   24413 non-null  object
#  17  Agency Name                     24413 non-null  object
#  18  prosecution-rate                24413 non-null  float64
# dtypes: float64(1), int64(5), object(13)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Merge with Demographics

# %%
modeling_data_l.head()
# Out:
#           RecordId  ClosedYear  MonthOccurrence   County  \
# 0  CA01-0000000001        2001                2  Alameda
# 1  CA01-0000000005        2001                2  Alameda
# 2  CA01-0000000003        2001                5  Alameda
# 3  CA01-0000000002        2001                9  Alameda
# 4  CA01-0000000004        2001                9  Alameda
#
#                                NCIC  TotalNumberOfVictims  \
# 0  Alameda Co. Sheriff's Department                     1
# 1  Alameda Co. Sheriff's Department                     2
# 2  Alameda Co. Sheriff's Department                     1
# 3  Alameda Co. Sheriff's Department                     1
# 4  Alameda Co. Sheriff's Department                     2
#
#    TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  TotalNumberOfSuspects  \
# 0                               1                White                      2
# 1                               2                White                      1
# 2                               1                White                      4
# 3                               1                White                      1
# 4                               2                White                      1
#
#                  MostSeriousUcr MostSeriousUcrType      MostSeriousLocation  \
# 0                Simple Assault     Violent Crimes           Bar/Night Club
# 1  Destruction/Damage/Vandalism    Property Crimes  Residence/Home/Driveway
# 2  Destruction/Damage/Vandalism    Property Crimes  Residence/Home/Driveway
# 3                  Intimidation     Violent Crimes  Residence/Home/Driveway
# 4                  Intimidation     Violent Crimes        Convenience Store
#
#                       MostSeriousBias      MostSeriousBiasType  \
# 0      Anti-Black or African American  Race/Ethnicity/Ancestry
# 1      Anti-Black or African American  Race/Ethnicity/Ancestry
# 2             Anti-Hispanic or Latino  Race/Ethnicity/Ancestry
# 3             Anti-Hispanic or Latino  Race/Ethnicity/Ancestry
# 4  Anti-Other Race/Ethnicity/Ancestry  Race/Ethnicity/Ancestry
#
#   MostSeriousVictimType                                   WeaponType  \
# 0                Person  Personal weapons (hands, feet, teeth, etc.)
# 1                Person                                         None
# 2                Person                                         None
# 3                Person                                         None
# 4                Person                                         None
#
#          Offensive_Act Agency Name  labels
# 0         Verbal slurs     Alameda       1
# 1             Graffiti     Alameda       1
# 2  Daubing of swastika     Alameda       1
# 3         Verbal slurs     Alameda       1
# 4         Verbal slurs     Alameda       1

# %%
#merge
modeling_data_l_demo = pd.merge(left=modeling_data_l, right=demographics, on='County')
modeling_data_r_demo = pd.merge(left=modeling_data_r, right=demographics, on='County')

# %%
# Drop columns that won't be used in modeling
modeling_data_l.drop(
    columns=["RecordId", "ClosedYear", "County", "NCIC", "Agency Name"], inplace=True
)
modeling_data_r.drop(
    columns=["RecordId", "ClosedYear", "County", "NCIC", "Agency Name"], inplace=True
)

# %%
# Drop columns that won't be used in modeling
modeling_data_l_demo.drop(
    columns=["RecordId", "ClosedYear", "County", "NCIC", "Agency Name"], inplace=True
)
modeling_data_r_demo.drop(
    columns=["RecordId", "ClosedYear", "County", "NCIC", "Agency Name"], inplace=True
)

# %% [markdown]
# ### Save DataFrames

# %%
modeling_data_l.to_csv("../data/classification_data.csv", index=False)
modeling_data_r.to_csv("../data/regression_data.csv", index=False)

# %%
modeling_data_l_demo.to_csv("../data/demographics-data/classification_data_demographics.csv", index=False)
modeling_data_r_demo.to_csv("../data/demographics-data/regression_data_demographics.csv", index=False)
