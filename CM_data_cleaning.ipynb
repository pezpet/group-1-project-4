# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
codebook_df = pd.read_excel("./base_data/County_codebook.xlsx")
df = pd.read_csv("./base_data/Hate-2001-2020.csv")

# %%
county_codes = codebook_df['CntyCode'].unique()
counties = codebook_df['County'].unique()

# %%
sliced_counties = []
for county in counties:
    sliced_counties.append(county[:-7])
county_dictionary = {county_codes[i] : sliced_counties[i] for i in range(len(county_codes))}

# %%
agency_dictionary = {}
for i in range(codebook_df.shape[0]):
    try:
        agency_dictionary[codebook_df['Code'][i].lstrip('0')] = codebook_df['Agency'][i]
    except:
        agency_dictionary[codebook_df['Code'][i]] = codebook_df['Agency'][i]

# %%
df['County'] = df['County'].map(county_dictionary)
df['NCIC'] = df['NCIC'].map(agency_dictionary)

# %%
df.to_csv("./base_data/mapped_HC.csv", index=False)

# %%
df = pd.read_csv("./base_data/mapped_HC.csv")

# %%
df.head()
# Out:
#           RecordId  ClosedYear  MonthOccurrence   County  \
# 0  CA01-0000000001        2001                2  Alameda
# 1  CA01-0000000005        2001                2  Alameda
# 2  CA01-0000000003        2001                5  Alameda
# 3  CA01-0000000002        2001                9  Alameda
# 4  CA01-0000000004        2001                9  Alameda
#
#                                NCIC  TotalNumberOfVictims  \
# 0  Alameda Co. Sheriff's Department                     1
# 1  Alameda Co. Sheriff's Department                     2
# 2  Alameda Co. Sheriff's Department                     1
# 3  Alameda Co. Sheriff's Department                     1
# 4  Alameda Co. Sheriff's Department                     2
#
#    TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  TotalNumberOfSuspects  \
# 0                               1                White                      2
# 1                               2                White                      1
# 2                               1                White                      4
# 3                               1                White                      1
# 4                               2                White                      1
#
#                  MostSeriousUcr  ...      MostSeriousBiasType  \
# 0                Simple Assault  ...  Race/Ethnicity/Ancestry
# 1  Destruction/Damage/Vandalism  ...  Race/Ethnicity/Ancestry
# 2  Destruction/Damage/Vandalism  ...  Race/Ethnicity/Ancestry
# 3                  Intimidation  ...  Race/Ethnicity/Ancestry
# 4                  Intimidation  ...  Race/Ethnicity/Ancestry
#
#   MostSeriousVictimType                                   WeaponType  \
# 0                Person  Personal weapons (hands, feet, teeth, etc.)
# 1                Person                                          NaN
# 2                Person                                          NaN
# 3                Person                                          NaN
# 4                Person                                          NaN
#
#          Offensive_Act IsMultipleBias TotalNumberOfIndividualVictimsAdult  \
# 0         Verbal slurs            NaN                                 NaN
# 1             Graffiti            NaN                                 NaN
# 2  Daubing of swastika            NaN                                 NaN
# 3         Verbal slurs            NaN                                 NaN
# 4         Verbal slurs            NaN                                 NaN
#
#   TotalNumberOfIndividualVictimsJuvenile TotalNumberOfSuspectsAdult  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
#
#    TotalNumberOfSuspectsJuvenile  SuspectsEthnicityAsAGroup
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
#
# [5 rows x 23 columns]

# %%
df[(df['ClosedYear'] == 2004) & (df['County'] == "Alameda")]
# Out:
#              RecordId  ClosedYear  MonthOccurrence   County  \
# 5411  CA00-0000015217        2004                2  Alameda
# 5412  CA00-0000015122        2004                3  Alameda
# 5413  CA00-0000015123        2004                3  Alameda
# 5414  CA00-0000015356        2004                5  Alameda
# 5415  CA00-0000016280        2004                8  Alameda
# 5416  CA00-0000016353        2004               12  Alameda
# 5417  CA00-0000015569        2004                6  Alameda
# 5418  CA00-0000015640        2004                7  Alameda
# 5419  CA00-0000014997        2004                1  Alameda
# 5420  CA00-0000015359        2004                5  Alameda
# 5421  CA00-0000015360        2004                5  Alameda
# 5422  CA00-0000015616        2004                7  Alameda
# 5423  CA00-0000015957        2004                7  Alameda
# 5424  CA00-0000015955        2004                9  Alameda
# 5425  CA00-0000015956        2004                9  Alameda
# 5426  CA00-0000016185        2004                9  Alameda
# 5427  CA00-0000016380        2004               12  Alameda
# 5428  CA00-0000014949        2004                1  Alameda
# 5429  CA00-0000015069        2004                2  Alameda
# 5430  CA00-0000015153        2004                3  Alameda
# 5431  CA00-0000015973        2004                9  Alameda
# 5432  CA00-0000014982        2004                1  Alameda
# 5433  CA00-0000014983        2004                1  Alameda
# 5434  CA00-0000015499        2004                5  Alameda
# 5435  CA00-0000015568        2004                6  Alameda
# 5436  CA00-0000016404        2004               10  Alameda
# 5437  CA00-0000016407        2004               12  Alameda
# 5438  CA00-0000015245        2004                4  Alameda
# 5439  CA00-0000015819        2004                9  Alameda
# 5440  CA00-0000016287        2004               12  Alameda
# 5441  CA00-0000016316        2004                7  Alameda
# 5442  CA00-0000016318        2004                8  Alameda
# 5443  CA00-0000016315        2004               11  Alameda
# 5444  CA00-0000015529        2004                6  Alameda
# 5445  CA00-0000015583        2004                6  Alameda
# 5446  CA00-0000016405        2004               12  Alameda
# 5447  CA00-0000015858        2004                9  Alameda
# 5448  CA00-0000016252        2004               11  Alameda
#
#                                     NCIC  TotalNumberOfVictims  \
# 5411    Alameda Co. Sheriff's Department                     2
# 5412                             Alameda                     1
# 5413                             Alameda                     1
# 5414                             Alameda                     1
# 5415                             Alameda                     1
# 5416                             Alameda                     1
# 5417                              Albany                     1
# 5418                              Albany                     1
# 5419                            Berkeley                     1
# 5420                            Berkeley                     3
# 5421                            Berkeley                     1
# 5422                            Berkeley                     1
# 5423                            Berkeley                     1
# 5424                            Berkeley                     1
# 5425                            Berkeley                     1
# 5426                            Berkeley                     1
# 5427                            Berkeley                     1
# 5428                             Fremont                     1
# 5429                             Fremont                     1
# 5430                             Fremont                     1
# 5431                             Fremont                     1
# 5432                              Newark                     1
# 5433                              Newark                     1
# 5434                              Newark                     2
# 5435                             Oakland                     1
# 5436                             Oakland                     1
# 5437                             Oakland                     1
# 5438                          Pleasanton                     1
# 5439                          Pleasanton                     3
# 5440                          Pleasanton                     1
# 5441                         San Leandro                     1
# 5442                         San Leandro                     2
# 5443                         San Leandro                     1
# 5444  East Bay Reg. Park Dist. - Alameda                     1
# 5445                        CSU East Bay                     1
# 5446                              Dublin                     1
# 5447                         UC Berkeley                     7
# 5448                         UC Berkeley                     1
#
#       TotalNumberOfIndividualVictims       SuspectsRaceAsAGroup  \
# 5411                               2                    Unknown
# 5412                               1                      White
# 5413                               1                      White
# 5414                               0                    Unknown
# 5415                               0                    Unknown
# 5416                               1                      White
# 5417                               1                    Unknown
# 5418                               1                    Unknown
# 5419                               0                    Unknown
# 5420                               3                      White
# 5421                               1  Black or African American
# 5422                               1                    Unknown
# 5423                               1                    Unknown
# 5424                               1                    Unknown
# 5425                               1                    Unknown
# 5426                               1                    Unknown
# 5427                               1                      White
# 5428                               1                      White
# 5429                               0                    Unknown
# 5430                               1                      White
# 5431                               1   East Indian/Asian Indian
# 5432                               1                    Unknown
# 5433                               1                   Hispanic
# 5434                               2                      White
# 5435                               1  Black or African American
# 5436                               1  Black or African American
# 5437                               0                      White
# 5438                               1                      White
# 5439                               3                      White
# 5440                               1                    Unknown
# 5441                               1                    Unknown
# 5442                               2                    Unknown
# 5443                               1                   Hispanic
# 5444                               1  Black or African American
# 5445                               0                    Unknown
# 5446                               1                      White
# 5447                               7                      White
# 5448                               1     Asian/Pacific Islander
#
#       TotalNumberOfSuspects                MostSeriousUcr  ...  \
# 5411                      0                  Intimidation  ...
# 5412                      1  Destruction/Damage/Vandalism  ...
# 5413                      1                Simple Assault  ...
# 5414                      0  Destruction/Damage/Vandalism  ...
# 5415                      0  Destruction/Damage/Vandalism  ...
# 5416                      1                Simple Assault  ...
# 5417                      0                  Intimidation  ...
# 5418                      0                  Intimidation  ...
# 5419                      0  Destruction/Damage/Vandalism  ...
# 5420                      1                Simple Assault  ...
# 5421                      1  Destruction/Damage/Vandalism  ...
# 5422                      0  Destruction/Damage/Vandalism  ...
# 5423                      0  Destruction/Damage/Vandalism  ...
# 5424                      0  Destruction/Damage/Vandalism  ...
# 5425                      0  Destruction/Damage/Vandalism  ...
# 5426                      0                  Intimidation  ...
# 5427                      1                  Intimidation  ...
# 5428                      1                  Intimidation  ...
# 5429                      0  Destruction/Damage/Vandalism  ...
# 5430                      1  Destruction/Damage/Vandalism  ...
# 5431                      1                  Intimidation  ...
# 5432                      0  Destruction/Damage/Vandalism  ...
# 5433                      1                Simple Assault  ...
# 5434                      1                  Intimidation  ...
# 5435                      4                Simple Assault  ...
# 5436                      4            Aggravated Assault  ...
# 5437                      1  Destruction/Damage/Vandalism  ...
# 5438                      1                  Intimidation  ...
# 5439                      2                  Intimidation  ...
# 5440                      0                  Intimidation  ...
# 5441                      0  Destruction/Damage/Vandalism  ...
# 5442                      0  Destruction/Damage/Vandalism  ...
# 5443                      2  Destruction/Damage/Vandalism  ...
# 5444                      4            Aggravated Assault  ...
# 5445                      0  Destruction/Damage/Vandalism  ...
# 5446                      2                  Intimidation  ...
# 5447                      3                Simple Assault  ...
# 5448                      1                  Intimidation  ...
#
#           MostSeriousBiasType MostSeriousVictimType  \
# 5411  Race/Ethnicity/Ancestry                Person
# 5412  Race/Ethnicity/Ancestry                Person
# 5413  Race/Ethnicity/Ancestry                Person
# 5414                 Religion             Religious
# 5415                 Religion             Religious
# 5416       Sexual Orientation                Person
# 5417       Sexual Orientation                Person
# 5418       Sexual Orientation                Person
# 5419  Race/Ethnicity/Ancestry            Government
# 5420  Race/Ethnicity/Ancestry                Person
# 5421       Sexual Orientation                Person
# 5422       Sexual Orientation                Person
# 5423  Race/Ethnicity/Ancestry                Person
# 5424  Race/Ethnicity/Ancestry                Person
# 5425  Race/Ethnicity/Ancestry                Person
# 5426       Sexual Orientation                Person
# 5427       Sexual Orientation                Person
# 5428  Race/Ethnicity/Ancestry                Person
# 5429  Race/Ethnicity/Ancestry            Government
# 5430  Race/Ethnicity/Ancestry                Person
# 5431                 Religion                Person
# 5432  Race/Ethnicity/Ancestry                Person
# 5433       Sexual Orientation                Person
# 5434  Race/Ethnicity/Ancestry                Person
# 5435  Race/Ethnicity/Ancestry                Person
# 5436  Race/Ethnicity/Ancestry                Person
# 5437                 Religion             Religious
# 5438  Race/Ethnicity/Ancestry                Person
# 5439  Race/Ethnicity/Ancestry                Person
# 5440  Race/Ethnicity/Ancestry                Person
# 5441  Race/Ethnicity/Ancestry                Person
# 5442  Race/Ethnicity/Ancestry                Person
# 5443  Race/Ethnicity/Ancestry                Person
# 5444  Race/Ethnicity/Ancestry                Person
# 5445  Race/Ethnicity/Ancestry            Government
# 5446  Race/Ethnicity/Ancestry                Person
# 5447                 Religion                Person
# 5448       Sexual Orientation                Person
#
#                                          WeaponType  \
# 5411                                            NaN
# 5412                                            NaN
# 5413               Other ( bottle, rocks, spitting)
# 5414                                            NaN
# 5415                                            NaN
# 5416               Other ( bottle, rocks, spitting)
# 5417                                            NaN
# 5418                                            NaN
# 5419                                            NaN
# 5420    Personal weapons (hands, feet, teeth, etc.)
# 5421                                            NaN
# 5422                                            NaN
# 5423                                            NaN
# 5424                                            NaN
# 5425                                            NaN
# 5426                                            NaN
# 5427                                            NaN
# 5428                                            NaN
# 5429                                            NaN
# 5430                                            NaN
# 5431                                            NaN
# 5432                                            NaN
# 5433    Personal weapons (hands, feet, teeth, etc.)
# 5434                                            NaN
# 5435    Personal weapons (hands, feet, teeth, etc.)
# 5436    Personal weapons (hands, feet, teeth, etc.)
# 5437  Knife or other cutting or stabbing instrument
# 5438                                            NaN
# 5439                                        Vehicle
# 5440                                            NaN
# 5441                                            NaN
# 5442                                            NaN
# 5443                                            NaN
# 5444    Personal weapons (hands, feet, teeth, etc.)
# 5445                                            NaN
# 5446                                            NaN
# 5447               Other ( bottle, rocks, spitting)
# 5448                                            NaN
#
#                            Offensive_Act IsMultipleBias  \
# 5411                 Daubing of swastika            NaN
# 5412    Threatening letters/flyers/email            NaN
# 5413                        Verbal slurs            NaN
# 5414                            Graffiti            NaN
# 5415                            Graffiti            NaN
# 5416                        Verbal slurs            NaN
# 5417    Threatening letters/flyers/email            NaN
# 5418                            Graffiti            NaN
# 5419                 Daubing of swastika            NaN
# 5420                        Verbal slurs            NaN
# 5421                   Damage to vehicle            NaN
# 5422                   Damage to vehicle            NaN
# 5423                 Daubing of swastika            NaN
# 5424                            Graffiti            NaN
# 5425                   Damage to vehicle            NaN
# 5426    Threatening letters/flyers/email            NaN
# 5427        Annoying telephone calls/fax            NaN
# 5428                        Verbal slurs            NaN
# 5429                            Graffiti            NaN
# 5430                 Daubing of swastika            NaN
# 5431                        Verbal slurs            NaN
# 5432                            Graffiti            NaN
# 5433                        Verbal slurs            NaN
# 5434        Annoying telephone calls/fax            NaN
# 5435                        Verbal slurs            NaN
# 5436                        Verbal slurs            NaN
# 5437  Disturbing public assembly/meeting            NaN
# 5438                        Verbal slurs            NaN
# 5439                        Verbal slurs            NaN
# 5440        Annoying telephone calls/fax            NaN
# 5441                   Damage to vehicle            NaN
# 5442                            Graffiti            NaN
# 5443                   Damage to vehicle            NaN
# 5444                        Verbal slurs            NaN
# 5445                            Graffiti            NaN
# 5446        Annoying telephone calls/fax            NaN
# 5447                        Verbal slurs            NaN
# 5448    Threatening letters/flyers/email            NaN
#
#      TotalNumberOfIndividualVictimsAdult  \
# 5411                                 NaN
# 5412                                 NaN
# 5413                                 NaN
# 5414                                 NaN
# 5415                                 NaN
# 5416                                 NaN
# 5417                                 NaN
# 5418                                 NaN
# 5419                                 NaN
# 5420                                 NaN
# 5421                                 NaN
# 5422                                 NaN
# 5423                                 NaN
# 5424                                 NaN
# 5425                                 NaN
# 5426                                 NaN
# 5427                                 NaN
# 5428                                 NaN
# 5429                                 NaN
# 5430                                 NaN
# 5431                                 NaN
# 5432                                 NaN
# 5433                                 NaN
# 5434                                 NaN
# 5435                                 NaN
# 5436                                 NaN
# 5437                                 NaN
# 5438                                 NaN
# 5439                                 NaN
# 5440                                 NaN
# 5441                                 NaN
# 5442                                 NaN
# 5443                                 NaN
# 5444                                 NaN
# 5445                                 NaN
# 5446                                 NaN
# 5447                                 NaN
# 5448                                 NaN
#
#      TotalNumberOfIndividualVictimsJuvenile TotalNumberOfSuspectsAdult  \
# 5411                                    NaN                        NaN
# 5412                                    NaN                        NaN
# 5413                                    NaN                        NaN
# 5414                                    NaN                        NaN
# 5415                                    NaN                        NaN
# 5416                                    NaN                        NaN
# 5417                                    NaN                        NaN
# 5418                                    NaN                        NaN
# 5419                                    NaN                        NaN
# 5420                                    NaN                        NaN
# 5421                                    NaN                        NaN
# 5422                                    NaN                        NaN
# 5423                                    NaN                        NaN
# 5424                                    NaN                        NaN
# 5425                                    NaN                        NaN
# 5426                                    NaN                        NaN
# 5427                                    NaN                        NaN
# 5428                                    NaN                        NaN
# 5429                                    NaN                        NaN
# 5430                                    NaN                        NaN
# 5431                                    NaN                        NaN
# 5432                                    NaN                        NaN
# 5433                                    NaN                        NaN
# 5434                                    NaN                        NaN
# 5435                                    NaN                        NaN
# 5436                                    NaN                        NaN
# 5437                                    NaN                        NaN
# 5438                                    NaN                        NaN
# 5439                                    NaN                        NaN
# 5440                                    NaN                        NaN
# 5441                                    NaN                        NaN
# 5442                                    NaN                        NaN
# 5443                                    NaN                        NaN
# 5444                                    NaN                        NaN
# 5445                                    NaN                        NaN
# 5446                                    NaN                        NaN
# 5447                                    NaN                        NaN
# 5448                                    NaN                        NaN
#
#       TotalNumberOfSuspectsJuvenile  SuspectsEthnicityAsAGroup
# 5411                            NaN                        NaN
# 5412                            NaN                        NaN
# 5413                            NaN                        NaN
# 5414                            NaN                        NaN
# 5415                            NaN                        NaN
# 5416                            NaN                        NaN
# 5417                            NaN                        NaN
# 5418                            NaN                        NaN
# 5419                            NaN                        NaN
# 5420                            NaN                        NaN
# 5421                            NaN                        NaN
# 5422                            NaN                        NaN
# 5423                            NaN                        NaN
# 5424                            NaN                        NaN
# 5425                            NaN                        NaN
# 5426                            NaN                        NaN
# 5427                            NaN                        NaN
# 5428                            NaN                        NaN
# 5429                            NaN                        NaN
# 5430                            NaN                        NaN
# 5431                            NaN                        NaN
# 5432                            NaN                        NaN
# 5433                            NaN                        NaN
# 5434                            NaN                        NaN
# 5435                            NaN                        NaN
# 5436                            NaN                        NaN
# 5437                            NaN                        NaN
# 5438                            NaN                        NaN
# 5439                            NaN                        NaN
# 5440                            NaN                        NaN
# 5441                            NaN                        NaN
# 5442                            NaN                        NaN
# 5443                            NaN                        NaN
# 5444                            NaN                        NaN
# 5445                            NaN                        NaN
# 5446                            NaN                        NaN
# 5447                            NaN                        NaN
# 5448                            NaN                        NaN
#
# [38 rows x 23 columns]

# %%
cr = pd.read_csv("./base_data/conviction-rates.csv")

# %%
X = cr[['conviction-rate']]

# %%
X = np.round(X.astype('float32'),5)

# %%
X[X['conviction-rate'] == np.inf] = 1

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
X['labels'] = kmeans.labels_

# %%
X.groupby('labels').agg([np.mean, np.max, np.min, np.size])
# Out:
#        conviction-rate
#                   mean     amax     amin size
# labels
# 0             0.991500  1.31579  0.75000   89
# 1             0.010987  0.21538  0.00000  703
# 2             3.400000  4.00000  3.00000    5
# 3             0.444684  0.70588  0.23077  185
# 4             2.000000  2.00000  2.00000    4

# %%
X['label'] = X['labels'].map({0:0, 1:2, 2:1, 4:3, 3:4})

# %%
X.groupby('label').agg([np.mean, np.max, np.min, np.size])
# Out:
#       conviction-rate                        labels
#                  mean     amax     amin size   mean amax amin size
# label
# 0            0.991500  1.31579  0.75000   89    0.0    0    0   89
# 1            3.400000  4.00000  3.00000    5    2.0    2    2    5
# 2            0.010987  0.21538  0.00000  703    1.0    1    1  703
# 3            2.000000  2.00000  2.00000    4    4.0    4    4    4
# 4            0.444684  0.70588  0.23077  185    3.0    3    3  185

# %%
plt.scatter(X['label'], X['conviction-rate'])

# %%
df.head()
# Out:
#           RecordId  ClosedYear  MonthOccurrence   County  \
# 0  CA01-0000000001        2001                2  Alameda
# 1  CA01-0000000005        2001                2  Alameda
# 2  CA01-0000000003        2001                5  Alameda
# 3  CA01-0000000002        2001                9  Alameda
# 4  CA01-0000000004        2001                9  Alameda
#
#                                NCIC  TotalNumberOfVictims  \
# 0  Alameda Co. Sheriff's Department                     1
# 1  Alameda Co. Sheriff's Department                     2
# 2  Alameda Co. Sheriff's Department                     1
# 3  Alameda Co. Sheriff's Department                     1
# 4  Alameda Co. Sheriff's Department                     2
#
#    TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  TotalNumberOfSuspects  \
# 0                               1                White                      2
# 1                               2                White                      1
# 2                               1                White                      4
# 3                               1                White                      1
# 4                               2                White                      1
#
#                  MostSeriousUcr  ...      MostSeriousBiasType  \
# 0                Simple Assault  ...  Race/Ethnicity/Ancestry
# 1  Destruction/Damage/Vandalism  ...  Race/Ethnicity/Ancestry
# 2  Destruction/Damage/Vandalism  ...  Race/Ethnicity/Ancestry
# 3                  Intimidation  ...  Race/Ethnicity/Ancestry
# 4                  Intimidation  ...  Race/Ethnicity/Ancestry
#
#   MostSeriousVictimType                                   WeaponType  \
# 0                Person  Personal weapons (hands, feet, teeth, etc.)
# 1                Person                                          NaN
# 2                Person                                          NaN
# 3                Person                                          NaN
# 4                Person                                          NaN
#
#          Offensive_Act IsMultipleBias TotalNumberOfIndividualVictimsAdult  \
# 0         Verbal slurs            NaN                                 NaN
# 1             Graffiti            NaN                                 NaN
# 2  Daubing of swastika            NaN                                 NaN
# 3         Verbal slurs            NaN                                 NaN
# 4         Verbal slurs            NaN                                 NaN
#
#   TotalNumberOfIndividualVictimsJuvenile TotalNumberOfSuspectsAdult  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
#
#    TotalNumberOfSuspectsJuvenile  SuspectsEthnicityAsAGroup
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
#
# [5 rows x 23 columns]

# %%
cr['label'] = X['label']

# %%
cr.head(1)
# Out:
#    Unnamed: 0  Year Agency Name  conviction-rate  label
# 0           0  2004     Alameda              0.5      4

# %%
df.head(1)
# Out:
#           RecordId  ClosedYear  MonthOccurrence   County  \
# 0  CA01-0000000001        2001                2  Alameda
#
#                                NCIC  TotalNumberOfVictims  \
# 0  Alameda Co. Sheriff's Department                     1
#
#    TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  TotalNumberOfSuspects  \
# 0                               1                White                      2
#
#    MostSeriousUcr  ...      MostSeriousBiasType MostSeriousVictimType  \
# 0  Simple Assault  ...  Race/Ethnicity/Ancestry                Person
#
#                                     WeaponType Offensive_Act IsMultipleBias  \
# 0  Personal weapons (hands, feet, teeth, etc.)  Verbal slurs            NaN
#
#   TotalNumberOfIndividualVictimsAdult TotalNumberOfIndividualVictimsJuvenile  \
# 0                                 NaN                                    NaN
#
#   TotalNumberOfSuspectsAdult  TotalNumberOfSuspectsJuvenile  \
# 0                        NaN                            NaN
#
#    SuspectsEthnicityAsAGroup
# 0                        NaN
#
# [1 rows x 23 columns]

# %%
df['label'] = np.NAN

# %%
df['reference'] = df['ClosedYear'].map(str) + df['County']
cr['reference'] = cr['Year'].map(str) + cr['Agency Name']

# %%
ref_dict = {cr['reference'][i] : cr['label'][i] for i in range(len(cr['reference']))}

# %%
df['label'] = df['reference'].map(ref_dict)

# %%
df = df.drop(df[df['ClosedYear'] < 2004].index)

# %%
df.shape
# Out:
# (19025, 25)

# %%
df.head()
# Out:
#              RecordId  ClosedYear  MonthOccurrence   County  \
# 5411  CA00-0000015217        2004                2  Alameda
# 5412  CA00-0000015122        2004                3  Alameda
# 5413  CA00-0000015123        2004                3  Alameda
# 5414  CA00-0000015356        2004                5  Alameda
# 5415  CA00-0000016280        2004                8  Alameda
#
#                                   NCIC  TotalNumberOfVictims  \
# 5411  Alameda Co. Sheriff's Department                     2
# 5412                           Alameda                     1
# 5413                           Alameda                     1
# 5414                           Alameda                     1
# 5415                           Alameda                     1
#
#       TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  \
# 5411                               2              Unknown
# 5412                               1                White
# 5413                               1                White
# 5414                               0              Unknown
# 5415                               0              Unknown
#
#       TotalNumberOfSuspects                MostSeriousUcr  ...  \
# 5411                      0                  Intimidation  ...
# 5412                      1  Destruction/Damage/Vandalism  ...
# 5413                      1                Simple Assault  ...
# 5414                      0  Destruction/Damage/Vandalism  ...
# 5415                      0  Destruction/Damage/Vandalism  ...
#
#                             WeaponType                     Offensive_Act  \
# 5411                               NaN               Daubing of swastika
# 5412                               NaN  Threatening letters/flyers/email
# 5413  Other ( bottle, rocks, spitting)                      Verbal slurs
# 5414                               NaN                          Graffiti
# 5415                               NaN                          Graffiti
#
#      IsMultipleBias TotalNumberOfIndividualVictimsAdult  \
# 5411            NaN                                 NaN
# 5412            NaN                                 NaN
# 5413            NaN                                 NaN
# 5414            NaN                                 NaN
# 5415            NaN                                 NaN
#
#      TotalNumberOfIndividualVictimsJuvenile TotalNumberOfSuspectsAdult  \
# 5411                                    NaN                        NaN
# 5412                                    NaN                        NaN
# 5413                                    NaN                        NaN
# 5414                                    NaN                        NaN
# 5415                                    NaN                        NaN
#
#      TotalNumberOfSuspectsJuvenile SuspectsEthnicityAsAGroup  label  \
# 5411                           NaN                       NaN    4.0
# 5412                           NaN                       NaN    4.0
# 5413                           NaN                       NaN    4.0
# 5414                           NaN                       NaN    4.0
# 5415                           NaN                       NaN    4.0
#
#         reference
# 5411  2004Alameda
# 5412  2004Alameda
# 5413  2004Alameda
# 5414  2004Alameda
# 5415  2004Alameda
#
# [5 rows x 25 columns]

# %%
df['label'].unique()
# Out:
# array([ 4.,  2.,  0.,  1.,  3., nan])

# %%
df.drop(columns=['reference'], inplace=True)

# %%
df.head()
# Out:
#              RecordId  ClosedYear  MonthOccurrence   County  \
# 5411  CA00-0000015217        2004                2  Alameda
# 5412  CA00-0000015122        2004                3  Alameda
# 5413  CA00-0000015123        2004                3  Alameda
# 5414  CA00-0000015356        2004                5  Alameda
# 5415  CA00-0000016280        2004                8  Alameda
#
#                                   NCIC  TotalNumberOfVictims  \
# 5411  Alameda Co. Sheriff's Department                     2
# 5412                           Alameda                     1
# 5413                           Alameda                     1
# 5414                           Alameda                     1
# 5415                           Alameda                     1
#
#       TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  \
# 5411                               2              Unknown
# 5412                               1                White
# 5413                               1                White
# 5414                               0              Unknown
# 5415                               0              Unknown
#
#       TotalNumberOfSuspects                MostSeriousUcr  ...  \
# 5411                      0                  Intimidation  ...
# 5412                      1  Destruction/Damage/Vandalism  ...
# 5413                      1                Simple Assault  ...
# 5414                      0  Destruction/Damage/Vandalism  ...
# 5415                      0  Destruction/Damage/Vandalism  ...
#
#      MostSeriousVictimType                        WeaponType  \
# 5411                Person                               NaN
# 5412                Person                               NaN
# 5413                Person  Other ( bottle, rocks, spitting)
# 5414             Religious                               NaN
# 5415             Religious                               NaN
#
#                          Offensive_Act IsMultipleBias  \
# 5411               Daubing of swastika            NaN
# 5412  Threatening letters/flyers/email            NaN
# 5413                      Verbal slurs            NaN
# 5414                          Graffiti            NaN
# 5415                          Graffiti            NaN
#
#      TotalNumberOfIndividualVictimsAdult  \
# 5411                                 NaN
# 5412                                 NaN
# 5413                                 NaN
# 5414                                 NaN
# 5415                                 NaN
#
#      TotalNumberOfIndividualVictimsJuvenile TotalNumberOfSuspectsAdult  \
# 5411                                    NaN                        NaN
# 5412                                    NaN                        NaN
# 5413                                    NaN                        NaN
# 5414                                    NaN                        NaN
# 5415                                    NaN                        NaN
#
#      TotalNumberOfSuspectsJuvenile  SuspectsEthnicityAsAGroup  label
# 5411                           NaN                        NaN    4.0
# 5412                           NaN                        NaN    4.0
# 5413                           NaN                        NaN    4.0
# 5414                           NaN                        NaN    4.0
# 5415                           NaN                        NaN    4.0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19025 entries, 5411 to 24435
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   RecordId                                19025 non-null  object
#  1   ClosedYear                              19025 non-null  int64
#  2   MonthOccurrence                         19025 non-null  int64
#  3   County                                  19025 non-null  object
#  4   NCIC                                    19025 non-null  object
#  5   TotalNumberOfVictims                    19025 non-null  int64
#  6   TotalNumberOfIndividualVictims          19025 non-null  int64
#  7   SuspectsRaceAsAGroup                    19025 non-null  object
#  8   TotalNumberOfSuspects                   19025 non-null  int64
#  9   MostSeriousUcr                          19025 non-null  object
#  10  MostSeriousUcrType                      19025 non-null  object
#  11  MostSeriousLocation                     19025 non-null  object
#  12  MostSeriousBias                         19025 non-null  object
#  13  MostSeriousBiasType                     19025 non-null  object
#  14  MostSeriousVictimType                   19025 non-null  object
#  15  WeaponType                              10386 non-null  object
#  16  Offensive_Act                           18722 non-null  object
#  17  IsMultipleBias                          24 non-null     object
#  18  TotalNumberOfIndividualVictimsAdult     5963 non-null   float64
#  19  TotalNumberOfIndividualVictimsJuvenile  5963 non-null   float64
#  20  TotalNumberOfSuspectsAdult              5963 non-null   float64
#  21  TotalNumberOfSuspectsJuvenile           5963 non-null   float64
#  22  SuspectsEthnicityAsAGroup               4813 non-null   object
#  23  label                                   18297 non-null  float64
# dtypes: float64(5), int64(5), object(14)
# memory usage: 3.6+ MB

# %%
df.drop(df.iloc[:, 17:23], axis=1, inplace=True)

# %%
df['WeaponType'].fillna('None', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19025 entries, 5411 to 24435
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RecordId                        19025 non-null  object
#  1   ClosedYear                      19025 non-null  int64
#  2   MonthOccurrence                 19025 non-null  int64
#  3   County                          19025 non-null  object
#  4   NCIC                            19025 non-null  object
#  5   TotalNumberOfVictims            19025 non-null  int64
#  6   TotalNumberOfIndividualVictims  19025 non-null  int64
#  7   SuspectsRaceAsAGroup            19025 non-null  object
#  8   TotalNumberOfSuspects           19025 non-null  int64
#  9   MostSeriousUcr                  19025 non-null  object
#  10  MostSeriousUcrType              19025 non-null  object
#  11  MostSeriousLocation             19025 non-null  object
#  12  MostSeriousBias                 19025 non-null  object
#  13  MostSeriousBiasType             19025 non-null  object
#  14  MostSeriousVictimType           19025 non-null  object
#  15  WeaponType                      19025 non-null  object
#  16  Offensive_Act                   18722 non-null  object
#  17  label                           18297 non-null  float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 2.8+ MB

# %%
df['Offensive_Act'].fillna('Other', inplace=True)

# %%
df['label'].fillna("None", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19025 entries, 5411 to 24435
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RecordId                        19025 non-null  object
#  1   ClosedYear                      19025 non-null  int64
#  2   MonthOccurrence                 19025 non-null  int64
#  3   County                          19025 non-null  object
#  4   NCIC                            19025 non-null  object
#  5   TotalNumberOfVictims            19025 non-null  int64
#  6   TotalNumberOfIndividualVictims  19025 non-null  int64
#  7   SuspectsRaceAsAGroup            19025 non-null  object
#  8   TotalNumberOfSuspects           19025 non-null  int64
#  9   MostSeriousUcr                  19025 non-null  object
#  10  MostSeriousUcrType              19025 non-null  object
#  11  MostSeriousLocation             19025 non-null  object
#  12  MostSeriousBias                 19025 non-null  object
#  13  MostSeriousBiasType             19025 non-null  object
#  14  MostSeriousVictimType           19025 non-null  object
#  15  WeaponType                      19025 non-null  object
#  16  Offensive_Act                   19025 non-null  object
#  17  label                           19025 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 2.8+ MB

# %%
df.to_csv("./cleaned_hatecrime.csv")
